# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# !pwd
# Out:
# /Users/mh/Desktop/Data-Science-Projects/Customer-Churn-Prediction/notebooks

# %%
df = pd.read_csv('../data/customer_churn.csv')
df.head(2)
# Out:
#               Names   Age  Total_Purchase  Account_Manager  Years  Num_Sites  \
# 0  Cameron Williams  42.0        11066.80                0   7.22        8.0
# 1     Kevin Mueller  41.0        11916.22                0   6.50       11.0
#
#           Onboard_date                                           Location  \
# 0  2013-08-30 07:00:40      10265 Elizabeth Mission Barkerburgh, AK 89518
# 1  2013-08-13 00:38:46  6157 Frank Gardens Suite 019 Carloshaven, RI 1...
#
#       Company  Churn
# 0  Harvey LLC      1
# 1  Wilson PLC      1

# %%
# drop column Names, Location and Company
# removing the columns that are not needed for the model building
# only numerical data is needed for the model building

df.drop(['Names','Location','Company', 'Onboard_date'],axis=1,inplace=True)

# %%
# datatypes of columns
df.dtypes
# Out:
# Age                float64
# Total_Purchase     float64
# Account_Manager      int64
# Years              float64
# Num_Sites          float64
# Churn                int64
# dtype: object
